# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("output_tables/ri_rewards.csv")
df.columns=['episodes', 'avg rewards']
df
# Out:
#     episodes  avg rewards
# 0        200      -0.0500
# 1        300      -0.0395
# 2        400      -0.0500
# 3        500      -0.0500
# 4        600      -0.0500
# 5        700      -0.0500
# 6        800      -0.0500
# 7        900      -0.0500
# 8       1000      -0.0500
# 9       1100      -0.0500
# 10      1200      -0.0500
# 11      1300      -0.0500
# 12      1400      -0.0500
# 13      1500      -0.0500
# 14      1600      -0.0500
# 15      1700      -0.0395
# 16      1800      -0.0500
# 17      1900       0.2545
# 18      2000       0.5905
# 19      2100       0.6325
# 20      2200       0.5275
# 21      2300       0.5590
# 22      2400       0.6010
# 23      2500       0.7060
# 24      2600       0.6325
# 25      2700       0.5485
# 26      2800       0.5275
# 27      2900       0.5800
# 28      3000       0.4960
# 29      3100       0.6010
# ..       ...          ...
# 69      7100       0.6745
# 70      7200       0.5590
# 71      7300       0.6010
# ...

# %%
fig, ax = plt.subplots(figsize=(14,8))



df.plot(x='episodes', y='avg rewards', ax=ax)
