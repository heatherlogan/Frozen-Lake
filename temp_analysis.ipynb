# %%
import os
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns

# %%
def sort_df(df):

    cols = [x*100 for x in range(1,101)]
    df.columns = cols

    for col in cols:
        df[col] = df[col].apply(lambda x: x.replace("'", '') if x==x else '')
        df[col] = df[col].apply(lambda x: float(x) if x==x else '')

    avgs = df.mean(axis=0)
    df.loc['averages'] = pd.Series(avgs)
    df = df.transpose()
    return df

# %%
y = simple_df[simple_df.columns[-4000:]]
y.shape
# Out:
# (500, 8)

# %%
simple_df = sort_df(pd.read_csv("500000 episodes/simple_rewards_per_100.csv"))
simple_df = simple_df.head(100)

fig = plt.figure()
ax = fig.add_subplot(111)

ax = simple_df['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.
plt.axvline(x=5000, c='red')


ax.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)

random_df = sort_df(pd.read_csv
                    ('rl_rewards_per_100_4x4-base.csv'))


ax = random_df['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='training stops')
plt.axvline(x=800, c='green', label='convergence point')


plt.title('Rewards per 100 episodes achieved by Random Agent over 8 Problems\n', fontsize=17)

ax.legend()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


ax = simple_df['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red')
plt.title('Rewards per 100 episodes achieved by Simple Agent over 8 Problems\n', fontsize=17)
ax.legend()

# %%
rl_df = sort_df(pd.read_csv("output_tables/rl_rewards_per_100.csv"))

fig = plt.figure()
ax = fig.add_subplot(111)


ax = rl_df['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.axvline(x=1200, c='green', label='Convergence Point')
plt.title('Learning Behaviour of Reinformement Agent over 8 Problems\n reward_hole=0.5, alpha=0.1 gamma=0.9\n', fontsize=17)
ax.legend(loc=4)

# %%
# with reward hole = -0.5

fig = plt.figure()
ax = fig.add_subplot(111)


ax = rl_df['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.axvline(x=3200, c='green', label='Convergence Point')
plt.title('Learning Behaviour of Reinformement Agent over 8 Problems\n alpha=0.1 gamma=0.9, reward_hole = -0.5 \n', fontsize=17)
ax.legend(loc=4)

# %%
ax = rl_df_2['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.axvline(x=1600, c='green', label='Convergence Point')
plt.title('Learning Behaviour of Reinformement Agent over 8 Problems\n alpha=0.1 gamma=0.9, reward_hole = -0.25 \n', fontsize=17)
ax.legend(loc=4)

# %%
ax = rl_df_3['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.axvline(x=1700, c='green', label='Convergence Point')
plt.title('Learning Behaviour of Reinformement Agent over 8 Problems\n alpha=0.1 gamma=0.9, reward_hole = -1.0 \n', fontsize=17)
ax.legend(loc=4)

# %%
rl_df_all = pd.read_csv("output_tables/rl_agent_8x8-base.csv")
rl_df_all = rl_df_all.set_index('problem_id')
rl_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                   5516.0           4484.0             14.295141
# 1                   8794.0           1206.0             10.011826
# 2                   5985.0           4015.0             22.853968
# 3                   1202.0           8022.0             10.730449
# 4                   1167.0           8207.0              9.874036
# 5                   1667.0           7658.0             11.123575
# 6                    243.0           9734.0             19.814815
# 7                   4750.0           5250.0              9.000632
# averages            3665.5           6072.0             13.463055
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               12.000                       64.000
# 1                               10.000                       36.000
# 2                                8.000                      150.000
# ...

# %%
rl_df_all = pd.read_csv("output_tables/rl_agent_8x8-base.csv")
rl_df_all = rl_df_all.set_index('problem_id')
rl_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                   5495.0          4505.00             14.324477
# 1                   8485.0          1515.00             10.013082
# 2                   3543.0          6454.00             17.204064
# 3                   3755.0          6245.00             27.681225
# 4                   1163.0          8105.00              9.739467
# 5                   2344.0          7638.00             11.697952
# 6                    199.0          8360.00             13.648241
# 7                   4704.0          5296.00              8.991284
# averages            3711.0          6014.75             14.162474
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               12.000                        58.00
# 1                               10.000                        32.00
# 2                                8.000                       108.00
# ...

# %%
random_df_all = pd.read_csv("output_tables/random_agent_8x8-base.csv")
random_df_all = random_df_all.set_index('problem_id')
random_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                      0.0          10000.0              0.000000
# 1                      1.0           9999.0             27.000000
# 2                     42.0           9958.0             24.214286
# 3                     10.0           9990.0             28.800000
# 4                      6.0           9994.0             31.666667
# 5                      5.0           9995.0             26.000000
# 6                      0.0          10000.0              0.000000
# 7                      8.0           9992.0             17.875000
# averages               9.0           9991.0             19.444494
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                                0.000                         0.00
# 1                               27.000                        27.00
# 2                               10.000                        49.00
# ...

# %%
print(random_df_all.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   steps to first goal \\
# problem\_id &                 &                  &                       &                             &                              &                       \\
# \midrule
# 0          &           0.000 &        10000.000 &              0.000000 &                        0.00 &                         0.00 &                 0.000 \\
# 1          &           3.000 &         9997.000 &             24.333333 &                       12.00 &                        40.00 &              8479.000 \\
# 2          &          34.000 &         9966.000 &             23.617647 &                       11.00 &                        68.00 &               341.000 \\
# ...

# %%
simple_df_all = pd.read_csv("output_tables/simple_agent_8x8-base.csv").set_index('problem_id')
simple_df_all = simple_df_all.set_index('problem_id')
simple_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                  10000.0              0.0                18.000
# 1                  10000.0              0.0                18.000
# 2                  10000.0              0.0                10.000
# 3                  10000.0              0.0                11.000
# 4                  10000.0              0.0                10.000
# 5                  10000.0              0.0                12.000
# 6                  10000.0              0.0                12.000
# 7                  10000.0              0.0                10.000
# averages           10000.0              0.0                12.625
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               18.000                       18.000
# 1                               18.000                       18.000
# 2                               10.000                       10.000
# ...

# %%
print(simple_df_all.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   steps to first goal \\
# problem\_id &                 &                  &                       &                             &                              &                       \\
# \midrule
# 0          &         10000.0 &              0.0 &                144.00 &                      144.00 &                       144.00 &                144.00 \\
# 1          &         10000.0 &              0.0 &                135.00 &                      135.00 &                       135.00 &                135.00 \\
# 2          &         10000.0 &              0.0 &                 92.00 &                       92.00 &                        92.00 &                 92.00 \\
# ...

# %%
# REWARD HOLE = 0.0
rl_df_all = pd.read_csv("output_tables/rl_agent_8x8-base.csv")
rl_df_all = rl_df_all.set_index('problem_id')
rl_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                 4424.000         5576.000             16.723779
# 1                 8118.000         1882.000             12.466248
# 2                 1965.000         8035.000             15.537913
# 3                 1027.000         8973.000             13.870497
# 4                  947.000         9053.000             12.408659
# 5                 2467.000         7533.000             17.055533
# 6                  225.000         9775.000             21.422222
# 7                 4524.000         5476.000             11.376216
# averages          2962.125         7037.875             15.107633
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               14.000                        46.00
# 1                               12.000                        43.00
# 2                               10.000                        64.00
# ...

# %%
print(rl_df_all.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   episodes to first reward \\
# problem\_id &                 &                  &                       &                             &                              &                            \\
# \midrule
# 0          &        4847.000 &         5153.000 &             16.856612 &                      14.000 &                         77.0 &                      365.0 \\
# 1          &        8228.000 &         1772.000 &             12.450778 &                      12.000 &                         28.0 &                      283.0 \\
# 2          &        3789.000 &         6211.000 &             19.476907 &                      10.000 &                         94.0 &                       35.0 \\
# ...

# %%
random_rewards = random_df_all[' total rewards']
random_rewards
# Out:
# problem_id
# 0            0.000
# 1            3.000
# 2           34.000
# 3            2.000
# 4            7.000
# 5            6.000
# 6            0.000
# 7            1.000
# averages     6.625
# Name:  total rewards, dtype: float64

# %%
all_rewards = pd.DataFrame({'Random':random_df_all[' total rewards'],
                          'Simple': simple_df_all[' total rewards'],
                          'RL': rl_df_all[' total rewards']})

all_rewards_percent = (all_rewards / 10000)*100
all_rewards_percent

ax = all_rewards_percent.plot(kind='line', figsize=(20,10), color=['royalblue','mediumorchid', 'mediumturquoise'])
ax.set_ylabel('Episodes Rewards were Achieved')
ax.legend(loc=1)

# %%
# Out:
#             Random  Simple        RL
# problem_id
# 0             0.00   100.0  44.24000
# 1             0.01   100.0  81.18000
# 2             0.42   100.0  19.65000
# 3             0.10   100.0  10.27000
# 4             0.06   100.0   9.47000
# 5             0.05   100.0  24.67000
# 6             0.00   100.0   2.25000
# 7             0.08   100.0  45.24000
# averages      0.09   100.0  29.62125

# %%
ax = all_rewards_percent.plot(kind='line', figsize=(20,10), color=['royalblue','mediumorchid', 'mediumturquoise'])
ax.set_ylabel('Episodes Rewards were Achieved')
# Out:
# Text(0, 0.5, 'Episodes Rewards were Achieved')

# %%
rl_df_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                 4424.000         5576.000             16.723779
# 1                 8118.000         1882.000             12.466248
# 2                 1965.000         8035.000             15.537913
# 3                 1027.000         8973.000             13.870497
# 4                  947.000         9053.000             12.408659
# 5                 2467.000         7533.000             17.055533
# 6                  225.000         9775.000             21.422222
# 7                 4524.000         5476.000             11.376216
# averages          2962.125         7037.875             15.107633
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               14.000                        46.00
# 1                               12.000                        43.00
# 2                               10.000                        64.00
# ...

# %%
episdoes_to_goal = pd.DataFrame({'Random':random_df_all[' episodes to first reward'],
                          'Simple': simple_df_all[' episodes to first reward'],
                          'RL': rl_df_all[' episodes to first reward']})

# %%
ax = episdoes_to_goal.loc['averages'].plot(kind='barh', figsize=(10,5), width=0.9)

ax.set_ylabel('Number of episodes to first goal')

x_offset= -0.1
y_offset=0.2

for p in ax.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='large')

# %%
# REWARD HOLE = 0.0
optimal_all = pd.read_csv("output_tables/optimal_simple_results.csv")
optimal_all = optimal_all.set_index('problem_id')
optimal_all
# Out:
#              total rewards   total failures   avg steps to reward  \
# problem_id
# 0                  10000.0              0.0                14.000
# 1                  10000.0              0.0                12.000
# 2                  10000.0              0.0                10.000
# 3                  10000.0              0.0                11.000
# 4                  10000.0              0.0                10.000
# 5                  10000.0              0.0                10.000
# 6                  10000.0              0.0                12.000
# 7                  10000.0              0.0                10.000
# averages           10000.0              0.0                11.125
#
#              best-case steps to reward   worst case steps to reward  \
# problem_id
# 0                               14.000                       14.000
# 1                               12.000                       12.000
# 2                               10.000                       10.000
# ...

# %%
random_df_all =  pd.read_csv("random_agent_4x4-base.csv").set_index('problem_id').head(3)
simple_df_all = pd.read_csv("simple_agent_4x4-base.csv").set_index('problem_id').head(3)
rl_df_all =  pd.read_csv("rl_agent_4x4-base.csv").set_index('problem_id').head(3)

avg_steps = pd.DataFrame({'Random':random_df_all[' avg steps to reward'],
                          'Simple': simple_df_all[' avg steps to reward'],
                          'RL': rl_df_all[' avg steps to reward']})

best_steps = pd.DataFrame({'Random':random_df_all[' best-case steps to reward'],
                          'Simple': simple_df_all[' best-case steps to reward'],
                          'RL': rl_df_all[' best-case steps to reward']})


worst_steps = pd.DataFrame({'Random':random_df_all[' worst case steps to reward'],
                          'Simple': simple_df_all[' worst case steps to reward'],
                          'RL': rl_df_all[' worst case steps to reward']})

avg_steps
# Out:
#                Random  Simple         RL
# problem_id
# 0            9.781565     4.0   4.134102
# 1           12.642857     6.0   7.655883
# 2           12.488426     6.0  13.826700

# %%
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(45, 10))
ax1 = axes[0]
ax2 = axes[1]
ax3 = axes[2]
                         
    
best_steps.plot(kind='bar', width=0.95, ax=ax1, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax1.set_ylabel('Number of episodes to first goal')
ax1.set_title('Best-case steps to reward', fontsize=20)
x_offset= -0.1
y_offset=0.2

for p in ax1.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax1.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='x-large')


avg_steps.plot(kind='bar', width=0.95, ax=ax2, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax2.set_title('Average steps to reward', fontsize=20)
x_offset= -0.1
y_offset=0.2

for p in ax2.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax2.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='x-large')
    

worst_steps.plot(kind='bar', width=0.95, ax=ax3, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax3.set_title('Worst-case steps to reward', fontsize=20)
x_offset= -0.1
y_offset=0.2

for p in ax3.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax3.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='x-large')
    
fig.savefig('')

# %%
ax = avg_steps.plot(kind='bar', figsize=(20,10), width=0.95, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax.set_ylabel('Number of episodes to first goal')
ax.set_title('Average steps to reward', fontsize=20)
x_offset= -0.1
y_offset=0.2

for p in ax.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='xx-large')

# %%
ax = best_steps.plot(kind='bar', figsize=(20,10), width=0.95, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax.set_ylabel('Number of episodes to first goal')
ax.set_title('Best-case steps to reward', fontsize=20)


x_offset= -0.1
y_offset=0.2

for p in ax.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='xx-large')

# %%
ax = worst_steps.plot(kind='bar', figsize=(20,10), width=0.95, colors=['royalblue','mediumorchid', 'mediumturquoise'])

ax.set_ylabel('Number of episodes to first goal')
ax.set_title('Worst-case steps to reward', fontsize=20)


x_offset= -0.1
y_offset=0.2

for p in ax.patches:
    b = p.get_bbox()
    val = "{}".format(int(b.y1 + b.y0)   )     
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset), fontsize='xx-large')

# %%
random_df_4 = sort_df(pd.read_csv("random_rewards_per_100_4x4-base.csv"))
simple_df_4 = sort_df(pd.read_csv("simple_rewards_per_100_4x4-base.csv"))
rl_df_4 = sort_df(pd.read_csv("rl_rewards_per_100_4x4-base.csv"))

# %%
random_4 = (pd.read_csv("random_agent_4x4-base.csv").set_index('problem_id'))
print(random_4.to_latex()
     )
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   episodes to first reward \\
# problem\_id &                 &                  &                       &                             &                              &                            \\
# \midrule
# 0          &     1336.000000 &      8664.000000 &              9.599551 &                    4.000000 &                    56.000000 &                        6.0 \\
# 1          &      240.000000 &      9760.000000 &             12.508333 &                    6.000000 &                    39.000000 &                       37.0 \\
# 2          &      432.000000 &      9568.000000 &             12.733796 &                    6.000000 &                    38.000000 &                        8.0 \\
# ...

# %%
simple_4 = (pd.read_csv("simple_agent_4x4-base.csv").set_index('problem_id'))
print(simple_4.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   episodes to first reward \\
# problem\_id &                 &                  &                       &                             &                              &                            \\
# \midrule
# 0          &         10000.0 &              0.0 &              4.000000 &                    4.000000 &                     4.000000 &                        1.0 \\
# 1          &         10000.0 &              0.0 &              6.000000 &                    6.000000 &                     6.000000 &                        1.0 \\
# 2          &         10000.0 &              0.0 &              6.000000 &                    6.000000 &                     6.000000 &                        1.0 \\
# ...

# %%
rl_4 = (pd.read_csv("rl_agent_4x4-base.csv").set_index('problem_id'))
print(rl_4.to_latex())
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
# {} &   total rewards &   total failures &   avg steps to reward &   best-case steps to reward &   worst case steps to reward &   episodes to first reward \\
# problem\_id &                 &                  &                       &                             &                              &                            \\
# \midrule
# 0          &     9627.000000 &       373.000000 &              4.134102 &                    4.000000 &                    20.000000 &                       14.0 \\
# 1          &     4853.000000 &      5147.000000 &              7.655883 &                    6.000000 &                    34.000000 &                       27.0 \\
# 2          &     4397.000000 &      5603.000000 &             13.826700 &                    6.000000 &                    83.000000 &                       16.0 \\
# ...

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


ax = random_df_4['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.title('Awards per 100 episodes acheived by Random Agent', fontsize=17)
# Out:
# Text(0.5, 1.0, 'Awards per 100 episodes acheived by Random Agent')

# %%
fig = plt.figure()
ax = fig.add_subplot(111)


ax = simple_df_4['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
# Out:
# Text(0, 0.5, 'Average rewards per 100 Episodes')

# %%
rl_df_4
# Out:
#            0      1  averages
# 100    0.070 -0.245   -0.0875
# 200    0.475 -0.275    0.1000
# 300    0.385 -0.140    0.1225
# 400    0.460 -0.155    0.1525
# 500    0.250 -0.110    0.0700
# 600    0.340 -0.245    0.0475
# 700    0.550 -0.230    0.1600
# 800    0.445 -0.215    0.1150
# 900    0.325 -0.185    0.0700
# 1000   0.475 -0.140    0.1675
# 1100   0.490 -0.215    0.1375
# 1200   0.295 -0.185    0.0550
# 1300   0.385 -0.170    0.1075
# 1400   0.445 -0.155    0.1450
# 1500   0.475 -0.230    0.1225
# 1600   0.415 -0.080    0.1675
# 1700   0.370 -0.245    0.0625
# 1800   0.460 -0.065    0.1975
# 1900   0.370 -0.245    0.0625
# 2000   0.505 -0.185    0.1600
# 2100   0.340 -0.170    0.0850
# 2200   0.355 -0.260    0.0475
# 2300   0.430 -0.125    0.1525
# 2400   0.370 -0.200    0.0850
# 2500   0.400 -0.230    0.0850
# 2600   0.265 -0.155    0.0550
# 2700   0.445 -0.155    0.1450
# 2800   0.325 -0.245    0.0400
# 2900   0.595 -0.260    0.1675
# 3000   0.445 -0.290    0.0775
# ...

# %%
rl_df_4 = sort_df(pd.read_csv("rl_rewards_per_100_4x4-base.csv"))

fig = plt.figure()
ax = fig.add_subplot(111)


ax = rl_df_4['averages'].plot(figsize=(20,10), label='Averages')
ax.grid(True)
plt.xlabel('Number of Episodes', fontsize=12)
plt.ylabel('Average rewards per 100 Episodes',  fontsize=12)
plt.axvline(x=5000, c='red', label='Training Stops')
plt.axvline(x=700, c='green', label='Convergence Point')
plt.title('Learning Behaviour of Reinformement Agent over 8 Problems\n alpha=0.1 gamma=0.95\n', fontsize=17)
ax.legend(loc=4)
